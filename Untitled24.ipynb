# %% [markdown]
# <a href="https://colab.research.google.com/github/amirmohammadkalateh/Xception/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
#keras applications
#include_top=True or false
#input_shape: optional shape tuple, only to be specified if include_top is False (otherwise the input shape has to be (299, 299, 3). It should have exactly 3 inputs channels, and width and height should be no smaller than 71. E.g. (150, 150, 3) would be one valid value.
keras.applications.Xception(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    name="xception",
)
# Out:
# <Functional name=xception, built=True>

# %% [markdown]
# # New Section

# %%
ship = ship.reshape(1, 549 , 976 , 3)/255
tf.resize(ship , [299 , 299])

# %%
ship = cv2.imread("ship.jpg")
plt.imshow(ship)
xception = keras.application.Xception()

# %%
y_prob = xception.predict(ship)

# %%
keras.applications.Xception.decode_predictions(y_prob , top=5)
